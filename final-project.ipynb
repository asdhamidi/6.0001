# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler

import tensorflow as tf

import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# # Exploratory Data Analysis Function

# %%
def scale_data(data, avoiding_columns):
    excluded_data = data[avoiding_columns]
    data = data.drop(avoiding_columns, axis=1)
    
    # Scale the data using standardization    
    scaler = MinMaxScaler()        
    scaled_data = scaler.fit_transform(data)
    
    # Convert the scaled data back to a DataFrame
    scaled_data = pd.DataFrame(scaled_data, columns=data.columns)
    scaled_data = pd.concat([scaled_data, excluded_data], axis=1)
    return scaled_data

# %%
def brainwave_mean_amplitude(data, target):    
    movement_class = data[target]
    data = data.iloc[:, :112]

    # Get unique class labels
    class_labels = movement_class.unique()

    # Calculate the mean of each column for each class
    means = []
    for label in class_labels:
        class_data = data[movement_class == label]
        class_means = class_data.median()
        means.append(class_means)

    # Create a horizontal bar chart with four data points in each bin
    num_columns = data.shape[1]
    y = np.arange(num_columns)
    height = 0.2

    plt.figure(figsize=(10, 25))
    for i, class_mean in enumerate(means):
        plt.barh(y + (i * height), class_mean, height=height, label=f'{class_labels[i]}')

    plt.ylabel('Brain Wave Columns')
    plt.xlabel('Median Amplitude')
    plt.title('Median Amplitude of Brain Wave Columns for Each Class')
    plt.yticks(y + ((len(class_labels) - 1) * height / 2), data.columns)
    plt.legend()
    plt.tight_layout()
    plt.savefig("fig1.png")
    plt.show()

# %%
def grouped_count(data, target):
    grouped_counts = data.groupby(target).size().reset_index(name='Count')

    # Display the result
    print(grouped_counts)

# %%
def correlation_analysis(data):
    # Calculate the correlations between variables
    corr = data.corr()
    top_correlations = corr.unstack()
    top_correlations = top_correlations[top_correlations.index.get_level_values(0) != top_correlations.index.get_level_values(1)]
    top_correlations = top_correlations.sort_values(ascending=False)[:50]
    print("Top correlations between the target variables:")
    print(top_correlations)

# %% [markdown]
# # Model Building Helper Functions

# %%
# Preprocess the inputs and split the data into train and test sets
def preprocess_inputs(df, target):
    df = df.copy()
    
    y = df[target].copy()
    X = df.drop(target, axis=1)

    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=123)

    scaler = StandardScaler()
    scaler.fit(X_train)

    X_train = pd.DataFrame(scaler.transform(X_train), columns=X.columns)
    X_test = pd.DataFrame(scaler.transform(X_test), columns=X.columns)

    return X_train, X_test, y_train, y_test

# %%
# Build the neural network model
def build_model(num_classes, neurons, X_train):
    inputs = tf.keras.Input(shape=(X_train.shape[1]))
    x = tf.keras.layers.Dense(neurons, activation='relu')(inputs)
    x = tf.keras.layers.Dense(neurons, activation='relu')(x)
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    model.compile(optimizer='adam',
                 loss='sparse_categorical_crossentropy',
                 metrics=['accuracy'])
    return model

# %%
# Plot the training and validation accuracy
def plot_results(model, history, X_test, y_test):
    train_acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    # Plot the accuracy graph
    plt.plot(train_acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Accuracy of Neural Network Model')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    # Generate predictions
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Generate classification report and confusion matrix
    report = classification_report(y_test, y_pred_classes)
    print("Classification Report:")
    print(report)

    cm = confusion_matrix(y_test, y_pred_classes)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.savefig("fig.png")
    plt.show()
    
    
    acc = model.evaluate(X_test, y_test)[1]
    print(f'Test Accuracy: {acc*100:.4f}')

# %%
def build_and_fit_model(data, target, neurons):
    # Preprocess the data
    X_train, X_test, y_train, y_test = preprocess_inputs(data, target)

    # Build and train the model
    model = build_model(num_classes=data[target].nunique(), neurons=neurons, X_train=X_train)
    history = model.fit(X_train,
                             y_train,
                             validation_split = 0.2,
                             batch_size = 32,
                             epochs = 50,
                            callbacks=[
            tf.keras.callbacks.EarlyStopping(
                monitor='val_loss',
                patience=5,
                restore_best_weights=True
            )
        ])

    # Evaluate the model
    plot_results(model, history, X_test, y_test)

# %% [markdown]
# # Case 1: Hands Movement

# %%
# Read the CSV files for each user and store them in a list
data = [pd.read_csv("../input/eeg-data-from-hands-movement/Dataset/user_" + user + ".csv") for user in ['a', 'b', 'c', 'd']]

# %%
for i in range(len(data)):
    data[i]['User'] = pd.Series(i, index = data[i].index)

# %%
# Concatenate all the DataFrames into a single DataFrame
data = pd.concat(data, axis=0)
data = data.sample(frac=1.0, random_state=123)  # Shuffle the data
data = data.reset_index(drop=True)

data = scale_data(data, ["Class", "User"])
data
# Out:
#        AF3 delta std  AF3 delta m  AF3 theta std  AF3 theta m  AF3 alpha std  \
# 0           0.568277     0.409038       0.054140     0.052791       0.065302
# 1           0.573529     0.411277       0.125349     0.095657       0.119535
# 2           0.518215     0.367084       0.059622     0.111547       0.074706
# 3           0.563813     0.403906       0.121586     0.085793       0.094098
# 4           0.533037     0.372712       0.067442     0.035380       0.170307
# ...              ...          ...            ...          ...            ...
# 11515       0.564038     0.400234       0.045955     0.031143       0.103656
# 11516       0.552350     0.396605       0.096309     0.085286       0.141880
# 11517       0.573729     0.406292       0.044842     0.035524       0.076160
# 11518       0.574169     0.413500       0.037969     0.079280       0.061420
# 11519       0.566569     0.405411       0.041332     0.070585       0.089411
#
#        AF3 alpha m  AF3 beta std  AF3 beta m  F7 delta std  F7 delta m  ...  \
# 0         0.094678      0.313560    0.343898      0.289335    0.193157  ...
# 1         0.086696      0.342578    0.444804      0.247403    0.225810  ...
# 2         0.102024      0.565462    0.568415      0.412661    0.211742  ...
# 3         0.117693      0.126075    0.265522      0.308275    0.165597  ...
# 4         0.107092      0.424324    0.509015      0.558821    0.314764  ...
# ...            ...           ...         ...           ...         ...  ...
# 11515     0.096892      0.092004    0.114535      0.222960    0.141284  ...
# 11516     0.106133      0.741190    0.433227      0.635851    0.335885  ...
# 11517     0.072258      0.333031    0.143084      0.338498    0.191006  ...
# 11518     0.033862      0.560824    0.301854      0.342238    0.180137  ...
# 11519     0.124213      0.134311    0.273595      0.252714    0.147657  ...
#
#        AF4 delta std  AF4 delta m  AF4 theta std  AF4 theta m  AF4 alpha std  \
# 0           0.876818     0.119994       0.055528     0.071357       0.080810
# 1           0.926154     0.134472       0.112727     0.149794       0.135256
# 2           0.791213     0.071293       0.056919     0.052148       0.006576
# 3           0.854176     0.112664       0.162871     0.065477       0.237475
# 4           0.767357     0.020200       0.014735     0.010390       0.004657
# ...              ...          ...            ...          ...            ...
# 11515       0.819096     0.052682       0.017806     0.006561       0.012698
# 11516       0.800650     0.045394       0.018211     0.011770       0.008131
# 11517       0.823470     0.053671       0.012779     0.008409       0.008946
# 11518       0.857781     0.081535       0.014985     0.013647       0.034301
# 11519       0.822114     0.053977       0.014221     0.006262       0.007579
#
#        AF4 alpha m  AF4 beta std  AF4 beta m  Class  User
# 0         0.212905      0.488260    0.457872    0.0     0
# 1         0.170903      0.265903    0.513134    1.0     0
# 2         0.044375      0.011068    0.029914    0.0     2
# 3         0.333865      0.362592    0.747762    0.0     0
# 4         0.019577      0.004911    0.008056    0.0     2
# ...            ...           ...         ...    ...   ...
# 11515     0.008607      0.009276    0.006959    2.0     3
# 11516     0.009023      0.019838    0.020900    1.0     2
# 11517     0.008382      0.012201    0.006531    0.0     1
# 11518     0.027078      0.376612    0.191480    0.0     0
# 11519     0.016153      0.010633    0.013932    1.0     1
#
# [11520 rows x 114 columns]

# %%
data.describe()
# Out:
#        AF3 delta std   AF3 delta m  AF3 theta std   AF3 theta m  \
# count   11520.000000  11520.000000   11520.000000  11520.000000
# mean        0.566405      0.407831       0.066677      0.066720
# std         0.023481      0.024257       0.040602      0.041764
# min         0.000000      0.000000       0.000000      0.000000
# 25%         0.559302      0.399421       0.042695      0.047886
# 50%         0.567050      0.406622       0.061346      0.061687
# 75%         0.573529      0.412993       0.082692      0.077285
# max         1.000000      1.000000       1.000000      1.000000
#
#        AF3 alpha std   AF3 alpha m  AF3 beta std    AF3 beta m  F7 delta std  \
# count   11520.000000  11520.000000  11520.000000  11520.000000  11520.000000
# mean        0.094087      0.079840      0.330974      0.299146      0.403132
# std         0.051627      0.038669      0.177420      0.141302      0.135524
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.058846      0.055607      0.184089      0.183617      0.294465
# 50%         0.086870      0.075899      0.314083      0.276389      0.377382
# 75%         0.120751      0.098789      0.446327      0.394887      0.501747
# max         1.000000      1.000000      1.000000      1.000000      1.000000
#
#          F7 delta m  ...  AF4 delta std   AF4 delta m  AF4 theta std  \
# count  11520.000000  ...   11520.000000  11520.000000   11520.000000
# mean       0.231753  ...       0.829609      0.067034       0.026039
# std        0.082263  ...       0.029868      0.027008       0.038383
# min        0.000000  ...       0.000000      0.000000       0.000000
# 25%        0.171070  ...       0.818892      0.052427       0.007876
# 50%        0.213056  ...       0.822317      0.054642       0.012475
# 75%        0.289151  ...       0.838073      0.077598       0.023758
# max        1.000000  ...       1.000000      1.000000       1.000000
#
#         AF4 theta m  AF4 alpha std   AF4 alpha m  AF4 beta std    AF4 beta m  \
# count  11520.000000   11520.000000  11520.000000  11520.000000  11520.000000
# mean       0.024253       0.026355      0.042665      0.111620      0.110645
# std        0.039004       0.042150      0.067114      0.194218      0.186644
# min        0.000000       0.000000      0.000000      0.000000      0.000000
# 25%        0.006393       0.006838      0.009714      0.008597      0.008946
# 50%        0.009259       0.010794      0.014586      0.012888      0.012800
# 75%        0.025929       0.020667      0.035761      0.067952      0.082069
# max        1.000000       1.000000      1.000000      1.000000      1.000000
#
#               Class          User
# count  11520.000000  11520.000000
# mean       1.000000      1.500000
# std        0.816532      1.118083
# min        0.000000      0.000000
# 25%        0.000000      0.750000
# 50%        1.000000      1.500000
# 75%        2.000000      2.250000
# max        2.000000      3.000000
#
# [8 rows x 114 columns]

# %%
brainwave_mean_amplitude(data, "Class")

# %%
brainwave_mean_amplitude(data, "User")

# %%
grouped_count(data, "Class")
# Out:
#    Class  Count
# 0    0.0   3840
# 1    1.0   3840
# 2    2.0   3840

# %%
grouped_count(data, "User")
# Out:
#    User  Count
# 0     0   2880
# 1     1   2880
# 2     2   2880
# 3     3   2880

# %%
correlation_analysis(data)
# Out:
# Top correlations between the target variables:
# AF4 beta std  FC6 beta std    0.997765
# FC6 beta std  AF4 beta std    0.997765
# AF4 beta std  P7 beta std     0.996561
# P7 beta std   AF4 beta std    0.996561
# AF4 beta std  F3 beta std     0.996010
# F3 beta std   AF4 beta std    0.996010
# P7 beta std   F8 beta std     0.995794
# F8 beta std   P7 beta std     0.995794
# F3 beta std   P7 beta std     0.995776
# P7 beta std   F3 beta std     0.995776
# FC6 beta std  F3 beta std     0.995673
# F3 beta std   FC6 beta std    0.995673
# FC6 beta std  P7 beta std     0.995261
# P7 beta std   FC6 beta std    0.995261
# FC6 beta m    AF4 beta m      0.994783
# AF4 beta m    FC6 beta m      0.994783
# T8 beta std   P7 beta std     0.994596
# P7 beta std   T8 beta std     0.994596
# F8 beta std   T8 beta std     0.992926
# T8 beta std   F8 beta std     0.992926
# AF4 beta std  T8 beta std     0.992485
# T8 beta std   AF4 beta std    0.992485
#               FC6 beta std    0.992176
# FC6 beta std  T8 beta std     0.992176
# F3 beta std   F8 beta std     0.991953
# F8 beta std   F3 beta std     0.991953
# P7 beta m     F3 beta m       0.991601
# F3 beta m     P7 beta m       0.991601
# AF4 beta std  F8 beta std     0.989852
# F8 beta std   AF4 beta std    0.989852
# P7 beta m     AF4 beta m      0.988487
# AF4 beta m    P7 beta m       0.988487
# FC6 beta std  P8 beta std     0.988381
# P8 beta std   FC6 beta std    0.988381
# FC6 beta m    P7 beta m       0.988367
# P7 beta m     FC6 beta m      0.988367
# T8 beta m     AF4 beta m      0.988202
# AF4 beta m    T8 beta m       0.988202
# P7 beta m     F8 beta m       0.988136
# F8 beta m     P7 beta m       0.988136
# T8 beta std   F3 beta std     0.987868
# F3 beta std   T8 beta std     0.987868
# F8 beta std   FC6 beta std    0.987726
# FC6 beta std  F8 beta std     0.987726
# T8 beta m     P7 beta m       0.987530
# P7 beta m     T8 beta m       0.987530
# F8 beta m     F3 beta m       0.986773
# F3 beta m     F8 beta m       0.986773
# FC6 beta m    T8 beta m       0.986453
# T8 beta m     FC6 beta m      0.986453
# dtype: float64

# %%
build_and_fit_model(data, "Class", 128)
# Out:
# Epoch 1/50
# 202/202 [==============================] - 2s 4ms/step - loss: 1.0801 - accuracy: 0.4216 - val_loss: 1.0187 - val_accuracy: 0.4544
# Epoch 2/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.9907 - accuracy: 0.4988 - val_loss: 0.9864 - val_accuracy: 0.5040
# Epoch 3/50
# 202/202 [==============================] - 0s 2ms/step - loss: 0.9334 - accuracy: 0.5405 - val_loss: 0.9609 - val_accuracy: 0.5251
# Epoch 4/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.8818 - accuracy: 0.5757 - val_loss: 0.9524 - val_accuracy: 0.5356
# Epoch 5/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.8473 - accuracy: 0.6048 - val_loss: 0.9281 - val_accuracy: 0.5549
# Epoch 6/50
# 202/202 [==============================] - 0s 2ms/step - loss: 0.7945 - accuracy: 0.6419 - val_loss: 0.9045 - val_accuracy: 0.5697
# Epoch 7/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.7554 - accuracy: 0.6580 - val_loss: 0.8944 - val_accuracy: 0.5914
# Epoch 8/50
# 202/202 [==============================] - 0s 2ms/step - loss: 0.7086 - accuracy: 0.6845 - val_loss: 0.9245 - val_accuracy: 0.5797
# Epoch 9/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.6763 - accuracy: 0.7047 - val_loss: 0.8817 - val_accuracy: 0.5945
# Epoch 10/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.6364 - accuracy: 0.7274 - val_loss: 0.8389 - val_accuracy: 0.6243
# Epoch 11/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.6041 - accuracy: 0.7479 - val_loss: 0.8186 - val_accuracy: 0.6330
# Epoch 12/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.5628 - accuracy: 0.7665 - val_loss: 0.8189 - val_accuracy: 0.6379
# Epoch 13/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.5204 - accuracy: 0.7842 - val_loss: 0.8293 - val_accuracy: 0.6280
# Epoch 14/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.4972 - accuracy: 0.8033 - val_loss: 0.8154 - val_accuracy: 0.6547
# Epoch 15/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.4744 - accuracy: 0.8095 - val_loss: 0.8281 - val_accuracy: 0.6553
# Epoch 16/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.4503 - accuracy: 0.8180 - val_loss: 0.8436 - val_accuracy: 0.6565
# Epoch 17/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.4130 - accuracy: 0.8322 - val_loss: 0.8652 - val_accuracy: 0.6479
# Epoch 18/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.4098 - accuracy: 0.8462 - val_loss: 0.8993 - val_accuracy: 0.6503
# Epoch 19/50
# 202/202 [==============================] - 0s 2ms/step - loss: 0.3932 - accuracy: 0.8479 - val_loss: 0.8769 - val_accuracy: 0.6528
# 109/109 [==============================] - 0s 1ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.60      0.63      1142
#          1.0       0.67      0.57      0.61      1191
#          2.0       0.56      0.72      0.63      1124
#
#     accuracy                           0.63      3457
#    macro avg       0.63      0.63      0.63      3457
# weighted avg       0.63      0.63      0.63      3457
# 109/109 [==============================] - 0s 1ms/step - loss: 0.8614 - accuracy: 0.6260
# Test Accuracy: 62.5976

# %%
build_and_fit_model(data, "User", 128)
# Out:
# Epoch 1/50
# 202/202 [==============================] - 2s 4ms/step - loss: 0.1214 - accuracy: 0.9633 - val_loss: 0.0208 - val_accuracy: 0.9950
# Epoch 2/50
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0120 - accuracy: 0.9969 - val_loss: 0.0092 - val_accuracy: 0.9988
# Epoch 3/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.0050 - accuracy: 0.9991 - val_loss: 0.0052 - val_accuracy: 0.9975
# Epoch 4/50
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 0.9994
# Epoch 5/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0028 - val_accuracy: 0.9994
# Epoch 6/50
# 202/202 [==============================] - 1s 3ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0020 - val_accuracy: 0.9994
# Epoch 7/50
# 202/202 [==============================] - 1s 2ms/step - loss: 5.8470e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 0.9994
# Epoch 8/50
# 202/202 [==============================] - 1s 2ms/step - loss: 2.7910e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 0.9994
# Epoch 9/50
# 202/202 [==============================] - 0s 2ms/step - loss: 2.5205e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 0.9994
# Epoch 10/50
# 202/202 [==============================] - 0s 2ms/step - loss: 1.4774e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 11/50
# 202/202 [==============================] - 1s 3ms/step - loss: 1.2066e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 0.9994
# Epoch 12/50
# 202/202 [==============================] - 1s 3ms/step - loss: 9.7710e-05 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 0.9994
# Epoch 13/50
# 202/202 [==============================] - 0s 2ms/step - loss: 8.7854e-05 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 0.9994
# Epoch 14/50
# 202/202 [==============================] - 1s 3ms/step - loss: 7.6363e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 0.9994
# Epoch 15/50
# 202/202 [==============================] - 1s 3ms/step - loss: 5.6952e-05 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 0.9994
# Epoch 16/50
# 202/202 [==============================] - 1s 3ms/step - loss: 5.3858e-05 - accuracy: 1.0000 - val_loss: 7.7828e-04 - val_accuracy: 1.0000
# Epoch 17/50
# 202/202 [==============================] - 1s 3ms/step - loss: 4.5002e-05 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 0.9994
# Epoch 18/50
# 202/202 [==============================] - 1s 3ms/step - loss: 3.7622e-05 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 0.9994
# Epoch 19/50
# 202/202 [==============================] - 1s 3ms/step - loss: 3.4926e-05 - accuracy: 1.0000 - val_loss: 7.1561e-04 - val_accuracy: 1.0000
# Epoch 20/50
# 202/202 [==============================] - 1s 3ms/step - loss: 2.7430e-05 - accuracy: 1.0000 - val_loss: 7.7514e-04 - val_accuracy: 1.0000
# Epoch 21/50
# 202/202 [==============================] - 0s 2ms/step - loss: 2.5417e-05 - accuracy: 1.0000 - val_loss: 8.8820e-04 - val_accuracy: 0.9994
# Epoch 22/50
# 202/202 [==============================] - 0s 2ms/step - loss: 2.1521e-05 - accuracy: 1.0000 - val_loss: 6.5833e-04 - val_accuracy: 1.0000
# Epoch 23/50
# 202/202 [==============================] - 0s 2ms/step - loss: 2.0778e-05 - accuracy: 1.0000 - val_loss: 6.8864e-04 - val_accuracy: 1.0000
# Epoch 24/50
# 202/202 [==============================] - 0s 2ms/step - loss: 2.0826e-05 - accuracy: 1.0000 - val_loss: 8.9778e-04 - val_accuracy: 0.9994
# Epoch 25/50
# 202/202 [==============================] - 0s 2ms/step - loss: 1.5899e-05 - accuracy: 1.0000 - val_loss: 6.7541e-04 - val_accuracy: 1.0000
# Epoch 26/50
# 202/202 [==============================] - 0s 2ms/step - loss: 1.2442e-05 - accuracy: 1.0000 - val_loss: 4.6269e-04 - val_accuracy: 1.0000
# Epoch 27/50
# 202/202 [==============================] - 0s 2ms/step - loss: 1.1028e-05 - accuracy: 1.0000 - val_loss: 5.0663e-04 - val_accuracy: 1.0000
# Epoch 28/50
# 202/202 [==============================] - 0s 2ms/step - loss: 9.6181e-06 - accuracy: 1.0000 - val_loss: 6.3321e-04 - val_accuracy: 0.9994
# Epoch 29/50
# 202/202 [==============================] - 1s 3ms/step - loss: 8.6253e-06 - accuracy: 1.0000 - val_loss: 4.1168e-04 - val_accuracy: 1.0000
# Epoch 30/50
# 202/202 [==============================] - 0s 2ms/step - loss: 8.8677e-06 - accuracy: 1.0000 - val_loss: 5.8495e-04 - val_accuracy: 1.0000
# Epoch 31/50
# 202/202 [==============================] - 1s 3ms/step - loss: 7.1519e-06 - accuracy: 1.0000 - val_loss: 6.1289e-04 - val_accuracy: 0.9994
# Epoch 32/50
# 202/202 [==============================] - 0s 2ms/step - loss: 5.4222e-06 - accuracy: 1.0000 - val_loss: 5.0606e-04 - val_accuracy: 1.0000
# Epoch 33/50
# 202/202 [==============================] - 1s 3ms/step - loss: 4.9403e-06 - accuracy: 1.0000 - val_loss: 4.3268e-04 - val_accuracy: 1.0000
# Epoch 34/50
# 202/202 [==============================] - 0s 2ms/step - loss: 4.2897e-06 - accuracy: 1.0000 - val_loss: 4.4550e-04 - val_accuracy: 1.0000
# 109/109 [==============================] - 0s 1ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       880
#            1       1.00      1.00      1.00       857
#            2       1.00      1.00      1.00       872
#            3       1.00      1.00      1.00       848
#
#     accuracy                           1.00      3457
#    macro avg       1.00      1.00      1.00      3457
# weighted avg       1.00      1.00      1.00      3457
# 109/109 [==============================] - 0s 1ms/step - loss: 0.0024 - accuracy: 0.9997
# Test Accuracy: 99.9711

# %% [markdown]
# # Case 2: Eye State

# %%
# Read the CSV files for each user and store them in a list
data = pd.read_csv("/kaggle/input/eye-state-classification-eeg-dataset/EEG_Eye_State_Classification.csv")

# %%
data.rename(columns={'eyeDetection': 'State'}, inplace=True)
data
# Out:
#            AF3       F7       F3      FC5       T7       P7       O1       O2  \
# 0      4329.23  4009.23  4289.23  4148.21  4350.26  4586.15  4096.92  4641.03
# 1      4324.62  4004.62  4293.85  4148.72  4342.05  4586.67  4097.44  4638.97
# 2      4327.69  4006.67  4295.38  4156.41  4336.92  4583.59  4096.92  4630.26
# 3      4328.72  4011.79  4296.41  4155.90  4343.59  4582.56  4097.44  4630.77
# 4      4326.15  4011.79  4292.31  4151.28  4347.69  4586.67  4095.90  4627.69
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 14975  4281.03  3990.26  4245.64  4116.92  4333.85  4614.36  4074.87  4625.64
# 14976  4276.92  3991.79  4245.13  4110.77  4332.82  4615.38  4073.33  4621.54
# 14977  4277.44  3990.77  4246.67  4113.85  4333.33  4615.38  4072.82  4623.59
# 14978  4284.62  3991.79  4251.28  4122.05  4334.36  4616.41  4080.51  4628.72
# 14979  4287.69  3997.44  4260.00  4121.03  4333.33  4616.41  4088.72  4638.46
#
#             P8       T8      FC6       F4       F8      AF4  State
# 0      4222.05  4238.46  4211.28  4280.51  4635.90  4393.85      0
# 1      4210.77  4226.67  4207.69  4279.49  4632.82  4384.10      0
# 2      4207.69  4222.05  4206.67  4282.05  4628.72  4389.23      0
# 3      4217.44  4235.38  4210.77  4287.69  4632.31  4396.41      0
# 4      4210.77  4244.10  4212.82  4288.21  4632.82  4398.46      0
# ...        ...      ...      ...      ...      ...      ...    ...
# 14975  4203.08  4221.54  4171.28  4269.23  4593.33  4340.51      1
# 14976  4194.36  4217.44  4162.56  4259.49  4590.26  4333.33      1
# 14977  4193.33  4212.82  4160.51  4257.95  4591.79  4339.49      1
# 14978  4200.00  4220.00  4165.64  4267.18  4596.41  4350.77      1
# 14979  4212.31  4226.67  4167.69  4274.36  4597.95  4350.77      1
#
# [14980 rows x 15 columns]

# %%
data.describe()
# Out:
#                  AF3            F7            F3            FC5            T7  \
# count   14980.000000  14980.000000  14980.000000   14980.000000  14980.000000
# mean     4321.917777   4009.767694   4264.022433    4164.946326   4341.741075
# std      2492.072174     45.941672     44.428052    5216.404632     34.738821
# min      1030.770000   2830.770000   1040.000000    2453.330000   2089.740000
# 25%      4280.510000   3990.770000   4250.260000    4108.210000   4331.790000
# 50%      4294.360000   4005.640000   4262.560000    4120.510000   4338.970000
# 75%      4311.790000   4023.080000   4270.770000    4132.310000   4347.180000
# max    309231.000000   7804.620000   6880.510000  642564.000000   6474.360000
#
#                   P7             O1            O2             P8  \
# count   14980.000000   14980.000000  14980.000000   14980.000000
# mean     4644.022379    4110.400160   4616.056904    4218.826610
# std      2924.789537    4600.926543     29.292603    2136.408523
# min      2768.210000    2086.150000   4567.180000    1357.950000
# 25%      4611.790000    4057.950000   4604.620000    4190.770000
# 50%      4617.950000    4070.260000   4613.330000    4199.490000
# 75%      4626.670000    4083.590000   4624.100000    4209.230000
# max    362564.000000  567179.000000   7264.100000  265641.000000
#
#                  T8           FC6            F4             F8            AF4  \
# count  14980.000000  14980.000000  14980.000000   14980.000000   14980.000000
# mean    4231.316200   4202.456900   4279.232774    4615.205336    4416.435832
# std       38.050903     37.785981     41.544312    1208.369958    5891.285043
# min     1816.410000   3273.330000   2257.950000      86.666700    1366.150000
# 25%     4220.510000   4190.260000   4267.690000    4590.770000    4342.050000
# 50%     4229.230000   4200.510000   4276.920000    4603.080000    4354.870000
# 75%     4239.490000   4211.280000   4287.180000    4617.440000    4372.820000
# max     6674.360000   6823.080000   7002.560000  152308.000000  715897.000000
#
#               State
# count  14980.000000
# mean       0.448798
# std        0.497388
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
brainwave_mean_amplitude(data, "State")

# %%
grouped_count(data, "State")
# Out:
#    State  Count
# 0      0   8257
# 1      1   6723

# %%
correlation_analysis(data)
# Out:
# Top correlations between the target variables:
# FC5  O1     0.999961
# O1   FC5    0.999961
# P8   AF3    0.999607
# AF3  P8     0.999607
# P8   F8     0.998849
# F8   P8     0.998849
# AF3  F8     0.998714
# F8   AF3    0.998714
# P7   AF4    0.988310
# AF4  P7     0.988310
# T8   O2     0.640387
# O2   T8     0.640387
# F7   F3     0.583317
# F3   F7     0.583317
# P8   FC6    0.577472
# FC6  P8     0.577472
# F8   FC6    0.577408
# FC6  F8     0.577408
# O2   F4     0.577013
# F4   O2     0.577013
# FC6  AF3    0.572997
# AF3  FC6    0.572997
# F3   FC6    0.517950
# FC6  F3     0.517950
# O2   F7     0.517816
# F7   O2     0.517816
# O1   F4     0.517621
# F4   O1     0.517621
# FC5  F4     0.515388
# F4   FC5    0.515388
# T7   FC5    0.504616
# FC5  T7     0.504616
# T7   O1     0.504231
# O1   T7     0.504231
# F3   F8     0.500276
# F8   F3     0.500276
# F7   T8     0.489010
# T8   F7     0.489010
# P8   F3     0.486506
# F3   P8     0.486506
# T7   AF4    0.478852
# AF4  T7     0.478852
# AF3  F3     0.474569
# F3   AF3    0.474569
# O2   FC6    0.433333
# FC6  O2     0.433333
# T8   P7     0.420539
# P7   T8     0.420539
# FC5  FC6    0.420311
# FC6  FC5    0.420311
# dtype: float64

# %%
build_and_fit_model(data, "State", 128)
# Out:
# Epoch 1/50
# 263/263 [==============================] - 1s 3ms/step - loss: 0.6168 - accuracy: 0.6670 - val_loss: 0.5480 - val_accuracy: 0.7173
# Epoch 2/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.5157 - accuracy: 0.7432 - val_loss: 0.4975 - val_accuracy: 0.7655
# Epoch 3/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.5059 - accuracy: 0.7752 - val_loss: 0.4665 - val_accuracy: 0.7817
# Epoch 4/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.4402 - accuracy: 0.7934 - val_loss: 0.4505 - val_accuracy: 0.7841
# Epoch 5/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.4178 - accuracy: 0.8066 - val_loss: 0.4219 - val_accuracy: 0.7969
# Epoch 6/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3937 - accuracy: 0.8186 - val_loss: 0.4149 - val_accuracy: 0.8117
# Epoch 7/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3804 - accuracy: 0.8255 - val_loss: 0.4010 - val_accuracy: 0.8060
# Epoch 8/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3652 - accuracy: 0.8319 - val_loss: 0.3952 - val_accuracy: 0.8141
# Epoch 9/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3567 - accuracy: 0.8391 - val_loss: 0.4245 - val_accuracy: 0.7969
# Epoch 10/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3486 - accuracy: 0.8393 - val_loss: 0.3754 - val_accuracy: 0.8279
# Epoch 11/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3332 - accuracy: 0.8499 - val_loss: 0.3631 - val_accuracy: 0.8294
# Epoch 12/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3481 - accuracy: 0.8488 - val_loss: 0.3825 - val_accuracy: 0.8213
# Epoch 13/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3481 - accuracy: 0.8482 - val_loss: 0.3680 - val_accuracy: 0.8270
# Epoch 14/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3166 - accuracy: 0.8568 - val_loss: 0.3505 - val_accuracy: 0.8432
# Epoch 15/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.3060 - accuracy: 0.8658 - val_loss: 0.3621 - val_accuracy: 0.8398
# Epoch 16/50
# 263/263 [==============================] - 1s 3ms/step - loss: 0.3016 - accuracy: 0.8690 - val_loss: 0.3375 - val_accuracy: 0.8556
# Epoch 17/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2960 - accuracy: 0.8693 - val_loss: 0.3429 - val_accuracy: 0.8446
# Epoch 18/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2894 - accuracy: 0.8752 - val_loss: 0.3325 - val_accuracy: 0.8489
# Epoch 19/50
# 263/263 [==============================] - 1s 3ms/step - loss: 0.2877 - accuracy: 0.8734 - val_loss: 0.3351 - val_accuracy: 0.8518
# Epoch 20/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2850 - accuracy: 0.8751 - val_loss: 0.3665 - val_accuracy: 0.8398
# Epoch 21/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2766 - accuracy: 0.8783 - val_loss: 0.3258 - val_accuracy: 0.8561
# Epoch 22/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2707 - accuracy: 0.8822 - val_loss: 0.3202 - val_accuracy: 0.8651
# Epoch 23/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2670 - accuracy: 0.8825 - val_loss: 0.3246 - val_accuracy: 0.8599
# Epoch 24/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2620 - accuracy: 0.8834 - val_loss: 0.3175 - val_accuracy: 0.8584
# Epoch 25/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2567 - accuracy: 0.8904 - val_loss: 0.3070 - val_accuracy: 0.8622
# Epoch 26/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2565 - accuracy: 0.8894 - val_loss: 0.3063 - val_accuracy: 0.8670
# Epoch 27/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2484 - accuracy: 0.8919 - val_loss: 0.3320 - val_accuracy: 0.8518
# Epoch 28/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2479 - accuracy: 0.8913 - val_loss: 0.3342 - val_accuracy: 0.8546
# Epoch 29/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2430 - accuracy: 0.8935 - val_loss: 0.3064 - val_accuracy: 0.8732
# Epoch 30/50
# 263/263 [==============================] - 1s 3ms/step - loss: 0.2367 - accuracy: 0.8960 - val_loss: 0.2985 - val_accuracy: 0.8699
# Epoch 31/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2366 - accuracy: 0.8996 - val_loss: 0.3082 - val_accuracy: 0.8618
# Epoch 32/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2350 - accuracy: 0.8990 - val_loss: 0.3090 - val_accuracy: 0.8651
# Epoch 33/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2296 - accuracy: 0.8988 - val_loss: 0.3162 - val_accuracy: 0.8622
# Epoch 34/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2246 - accuracy: 0.9034 - val_loss: 0.2952 - val_accuracy: 0.8737
# Epoch 35/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2242 - accuracy: 0.9044 - val_loss: 0.3146 - val_accuracy: 0.8565
# Epoch 36/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2206 - accuracy: 0.9057 - val_loss: 0.3885 - val_accuracy: 0.8437
# Epoch 37/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2229 - accuracy: 0.9006 - val_loss: 0.3046 - val_accuracy: 0.8694
# Epoch 38/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2101 - accuracy: 0.9100 - val_loss: 0.2902 - val_accuracy: 0.8842
# Epoch 39/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2080 - accuracy: 0.9107 - val_loss: 0.3373 - val_accuracy: 0.8694
# Epoch 40/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2076 - accuracy: 0.9102 - val_loss: 0.2953 - val_accuracy: 0.8780
# Epoch 41/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2041 - accuracy: 0.9119 - val_loss: 0.2936 - val_accuracy: 0.8737
# Epoch 42/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2026 - accuracy: 0.9156 - val_loss: 0.2953 - val_accuracy: 0.8775
# Epoch 43/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2011 - accuracy: 0.9133 - val_loss: 0.2843 - val_accuracy: 0.8761
# Epoch 44/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.1964 - accuracy: 0.9154 - val_loss: 0.3108 - val_accuracy: 0.8680
# Epoch 45/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.1924 - accuracy: 0.9188 - val_loss: 0.2818 - val_accuracy: 0.8832
# Epoch 46/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.1895 - accuracy: 0.9205 - val_loss: 0.3062 - val_accuracy: 0.8718
# Epoch 47/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2006 - accuracy: 0.9154 - val_loss: 0.2844 - val_accuracy: 0.8737
# Epoch 48/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2014 - accuracy: 0.9160 - val_loss: 0.2998 - val_accuracy: 0.8770
# Epoch 49/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.1859 - accuracy: 0.9230 - val_loss: 0.2868 - val_accuracy: 0.8789
# Epoch 50/50
# 263/263 [==============================] - 1s 2ms/step - loss: 0.1801 - accuracy: 0.9254 - val_loss: 0.2780 - val_accuracy: 0.8847
# 141/141 [==============================] - 0s 1ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90      2474
#            1       0.89      0.85      0.87      2020
#
#     accuracy                           0.89      4494
#    macro avg       0.89      0.89      0.89      4494
# weighted avg       0.89      0.89      0.89      4494
# 141/141 [==============================] - 0s 1ms/step - loss: 0.2614 - accuracy: 0.8885
# Test Accuracy: 88.8518
